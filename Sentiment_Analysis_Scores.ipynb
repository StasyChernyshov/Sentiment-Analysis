# %%
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# load model and tokenizer
roberta = "cardiffnlp/twitter-roberta-base-sentiment"
model = AutoModelForSequenceClassification.from_pretrained(roberta)
tokenizer = AutoTokenizer.from_pretrained(roberta)

# %%
# testing our sentiment analysis function
def sentiment_analysis(tweet):
# precprcess tweet
    tweet_words = []

    for word in tweet.split(' '):
        if word.startswith('@') and len(word) > 1:
            word = '@user'
        
        elif word.startswith('http'):
            word = "http"
        tweet_words.append(word)

    tweet_proc = " ".join(tweet_words)


    labels = ['Negative', 'Neutral', 'Positive']

    # sentiment analysis
    encoded_tweet = tokenizer(tweet_proc, return_tensors='pt')
    # output = model(encoded_tweet['input_ids'], encoded_tweet['attention_mask'])
    output = model(**encoded_tweet)

    scores = output[0][0].detach().numpy()
    scores = softmax(scores)

    for i in range(len(scores)):
        
        l = labels[i]
        s = scores[i]
        print(l,s)

    # Calculate compound score
    compound_score = np.dot(scores, [-1, 0, 1])
    print(f"Compound Score: {compound_score:.4}")

sentiment_analysis("testing out our wondefull  tweet, with roberta model")
# Out:
# Negative 0.012825836
# Neutral 0.73449975
# Positive 0.2526744
# Compound Score: 0.2398

# %%
# Define the file paths
file_path = 'Final_NYT_articles.csv'

# Read the CSV files
NYT_articles = pd.read_csv(file_path)

NYT_articles.head()
# Out:
#                    pub_date  \
# 0  2024-01-30T13:40:11+0000
# 1  2024-01-29T10:01:56+0000
# 2  2024-01-27T08:00:40+0000
# 3  2024-01-24T19:59:53+0000
# 4  2024-01-24T17:59:40+0000
#
#                                             headline  \
# 0  Saudi Aramco Abruptly Drops Plans to Expand Oi...
# 1  Where Southerners Go to Fill the Tank and Feed...
# 2  Democrats Say Biden Hasn’t ‘Made the Case’ on ...
# 3     Shipping Costs Soar in Wake of Red Sea Attacks
# 4  White House Said to Delay Decision on Enormous...
#
#                                             abstract  \
# 0  The pullback, at the behest of the Saudi gover...
# 1  Are they gas stations that serve food or resta...
# 2  The president likes to talk about his climate ...
# 3  Ships risking Houthi attacks must pay high ins...
# 4  Before deciding whether to approve it, the Ene...
#
#                                       lead_paragraph              byline  \
# 0  Saudi Aramco said Tuesday that it would call o...     By Stanley Reed
# 1  New York City has its bodegas. The South has i...     By Kim Severson
# 2  President Biden has done more than any preside...    By Lisa Friedman
# 3  For about two months, a barrage of missile and...     By Stanley Reed
# 4  The Biden administration is pausing a decision...  By Coral Davenport
#
#    section_name                                            web_url  \
# 0  Business Day  https://www.nytimes.com/2024/01/30/business/sa...
# 1          Food  https://www.nytimes.com/2024/01/29/dining/sout...
# 2       Climate  https://www.nytimes.com/2024/01/27/climate/bid...
# 3  Business Day  https://www.nytimes.com/2024/01/24/business/re...
# 4       Climate  https://www.nytimes.com/2024/01/24/climate/bid...
#
#                source                                     multimedia_url
# 0  The New York Times  https://www.nytimes.com/images/2024/01/30/mult...
# 1  The New York Times  https://www.nytimes.com/images/2024/01/31/mult...
# 2  The New York Times  https://www.nytimes.com/images/2024/01/26/mult...
# 3  The New York Times  https://www.nytimes.com/images/2024/01/23/mult...
# 4  The New York Times  https://www.nytimes.com/images/2024/01/24/mult...

# %%
NYT_articles.insert(0, 'article_count', range(1, len(NYT_articles) + 1))
NYT_articles.tail()
# Out:
#      article_count                  pub_date  \
# 144            145  2024-06-01T11:00:06+0000
# 145            146  2024-07-07T19:55:06+0000
# 146            147  2024-07-07T09:00:16+0000
# 147            148  2024-07-06T10:00:05+0000
# 148            149  2024-07-02T01:23:39+0000
#
#                                               headline  \
# 144  Oil and Gas Companies Are Trying to Rig the Ma...
# 145  Officials Urge Coastal Texans to Evacuate, but...
# 146  New Plan to Target Russia’s Oil Revenue Brings...
# 147  Facing New ‘Greenwashing’ Law, an Oil Industry...
# 148  Judge Orders Biden Administration to Resume Pe...
#
#                                               abstract  \
# 144  Fossil fuel interests are spreading misinforma...
# 145  Despite warnings that Beryl could be a “deadly...
# 146  Treasury officials want to impose penalties on...
# 147  Oil sands companies pushing a carbon capture p...
# 148  President Biden had paused new natural gas exp...
#
#                                         lead_paragraph  \
# 144  Many of us focused on the problem of climate c...
# 145  As Beryl chugged toward the Texas Gulf Coast o...
# 146  Officials in President Biden’s Treasury Depart...
# 147  When Parliament passed a law last month bannin...
# 148  A federal judge on Monday ordered the Biden ad...
#
#                                                 byline section_name  \
# 144                                  By Andrew Dessler      Opinion
# 145  By Edgar Sandoval, Maria Jimenez Moya and Jack...         U.S.
# 146               By Jim Tankersley and Alan Rappeport         U.S.
# 147                                      By Ian Austen        World
# 148                                 By Coral Davenport      Climate
#
#                                                web_url              source  \
# 144  https://www.nytimes.com/2024/06/01/opinion/cle...  The New York Times
# 145  https://www.nytimes.com/2024/07/07/us/texas-ev...  The New York Times
# 146  https://www.nytimes.com/2024/07/07/us/politics...  The New York Times
# 147  https://www.nytimes.com/2024/07/06/world/canad...  The New York Times
# 148  https://www.nytimes.com/2024/07/01/climate/fed...  The New York Times
#
#                                         multimedia_url
# 144  https://www.nytimes.com/images/2024/06/03/opin...
# 145  https://www.nytimes.com/images/2024/07/07/mult...
# 146  https://www.nytimes.com/images/2024/06/25/mult...
# 147  https://www.nytimes.com/images/2024/07/06/mult...
# 148  https://www.nytimes.com/images/2024/07/01/mult...

# %%
example = NYT_articles["headline"][4]
print(f"Example: {example}")
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'negative(sentiment_score_headline)' : scores[0],
        'neutral(sentiment_score_headline)' : scores[1],
        'positive(sentiment_score_headline)' : scores[2],
        'compound(sentiment_score_headline)' : np.dot(scores, [-1, 0, 1]) 
    }
    return scores_dict

polarity_scores_roberta(example)
# Out:
# Example: White House Said to Delay Decision on Enormous Natural Gas Export Terminal
# {'negative(sentiment_score_headline)': 0.19727972,
#  'neutral(sentiment_score_headline)': 0.7822566,
#  'positive(sentiment_score_headline)': 0.02046365,
#  'compound(sentiment_score_headline)': -0.17681607231497765}

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
from tqdm import tqdm
res = {}
for i, row in tqdm(NYT_articles.iterrows(), total=len(NYT_articles)):
    try:
        text = row['headline']
        myid = row['article_count']
        res[myid] = polarity_scores_roberta(text)
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
# 100%|██████████| 149/149 [00:04<00:00, 34.41it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'article_count'})
results_df = results_df.merge(NYT_articles, how='left')
results_df.head()
# Out:
#    article_count  negative(sentiment_score_headline)  \
# 0              1                            0.368058
# 1              2                            0.166938
# 2              3                            0.505036
# 3              4                            0.418735
# 4              5                            0.197280
#
#    neutral(sentiment_score_headline)  positive(sentiment_score_headline)  \
# 0                           0.601618                            0.030324
# 1                           0.778636                            0.054426
# 2                           0.465767                            0.029197
# 3                           0.560968                            0.020298
# 4                           0.782257                            0.020464
#
#    compound(sentiment_score_headline)                  pub_date  \
# 0                           -0.337734  2024-01-30T13:40:11+0000
# 1                           -0.112513  2024-01-29T10:01:56+0000
# 2                           -0.475839  2024-01-27T08:00:40+0000
# 3                           -0.398437  2024-01-24T19:59:53+0000
# 4                           -0.176816  2024-01-24T17:59:40+0000
#
#                                             headline  \
# 0  Saudi Aramco Abruptly Drops Plans to Expand Oi...
# 1  Where Southerners Go to Fill the Tank and Feed...
# 2  Democrats Say Biden Hasn’t ‘Made the Case’ on ...
# 3     Shipping Costs Soar in Wake of Red Sea Attacks
# 4  White House Said to Delay Decision on Enormous...
#
#                                             abstract  \
# 0  The pullback, at the behest of the Saudi gover...
# 1  Are they gas stations that serve food or resta...
# 2  The president likes to talk about his climate ...
# 3  Ships risking Houthi attacks must pay high ins...
# 4  Before deciding whether to approve it, the Ene...
#
#                                       lead_paragraph              byline  \
# 0  Saudi Aramco said Tuesday that it would call o...     By Stanley Reed
# 1  New York City has its bodegas. The South has i...     By Kim Severson
# 2  President Biden has done more than any preside...    By Lisa Friedman
# 3  For about two months, a barrage of missile and...     By Stanley Reed
# 4  The Biden administration is pausing a decision...  By Coral Davenport
#
#    section_name                                            web_url  \
# 0  Business Day  https://www.nytimes.com/2024/01/30/business/sa...
# 1          Food  https://www.nytimes.com/2024/01/29/dining/sout...
# 2       Climate  https://www.nytimes.com/2024/01/27/climate/bid...
# 3  Business Day  https://www.nytimes.com/2024/01/24/business/re...
# 4       Climate  https://www.nytimes.com/2024/01/24/climate/bid...
#
#                source                                     multimedia_url
# 0  The New York Times  https://www.nytimes.com/images/2024/01/30/mult...
# 1  The New York Times  https://www.nytimes.com/images/2024/01/31/mult...
# 2  The New York Times  https://www.nytimes.com/images/2024/01/26/mult...
# 3  The New York Times  https://www.nytimes.com/images/2024/01/23/mult...
# 4  The New York Times  https://www.nytimes.com/images/2024/01/24/mult...

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
from tqdm import tqdm

# Load the model and tokenizer
model_name = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Define function to calculate polarity scores for abstracts
def polarity_scores_roberta_abstract(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'negative(sentiment_score_abstract)': scores[0],
        'neutral(sentiment_score_abstract)': scores[1],
        'positive(sentiment_score_abstract)': scores[2],
        'compound(sentiment_score_abstract)': np.dot(scores, [-1, 0, 1])
    }
    return scores_dict

# Load the results DataFrame (assuming it's named results_df)
# results_df = pd.read_csv('path_to_your_csv_file.csv') # Uncomment and set the correct path to your file

# Calculate sentiment scores for abstracts and store in a dictionary
res_abstract = {}
for i, row in tqdm(results_df.iterrows(), total=len(results_df)):
    try:
        text = row['abstract']
        myid = row['article_count']
        res_abstract[myid] = polarity_scores_roberta_abstract(text)
    except RuntimeError:
        print(f'Broke for id {myid}')

# Convert the results dictionary to a DataFrame
results_df_abstract = pd.DataFrame(res_abstract).T.reset_index().rename(columns={'index': 'article_count'})

# Ensure article_count is the same type in both DataFrames
results_df['article_count'] = results_df['article_count'].astype(str)
results_df_abstract['article_count'] = results_df_abstract['article_count'].astype(str)

# Merge the new DataFrame with the original one
results_df_final = results_df.merge(results_df_abstract, on='article_count', how='left')

# Display the head of the final DataFrame
results_df_final.head()
# Out:
# 100%|██████████| 149/149 [00:04<00:00, 30.58it/s]
#   article_count  negative(sentiment_score_headline)  \
# 0             1                            0.368058
# 1             2                            0.166938
# 2             3                            0.505036
# 3             4                            0.418735
# 4             5                            0.197280
#
#    neutral(sentiment_score_headline)  positive(sentiment_score_headline)  \
# 0                           0.601618                            0.030324
# 1                           0.778636                            0.054426
# 2                           0.465767                            0.029197
# 3                           0.560968                            0.020298
# 4                           0.782257                            0.020464
#
#    compound(sentiment_score_headline)                  pub_date  \
# 0                           -0.337734  2024-01-30T13:40:11+0000
# 1                           -0.112513  2024-01-29T10:01:56+0000
# 2                           -0.475839  2024-01-27T08:00:40+0000
# 3                           -0.398437  2024-01-24T19:59:53+0000
# 4                           -0.176816  2024-01-24T17:59:40+0000
#
#                                             headline  \
# 0  Saudi Aramco Abruptly Drops Plans to Expand Oi...
# 1  Where Southerners Go to Fill the Tank and Feed...
# 2  Democrats Say Biden Hasn’t ‘Made the Case’ on ...
# 3     Shipping Costs Soar in Wake of Red Sea Attacks
# 4  White House Said to Delay Decision on Enormous...
#
#                                             abstract  \
# 0  The pullback, at the behest of the Saudi gover...
# 1  Are they gas stations that serve food or resta...
# 2  The president likes to talk about his climate ...
# 3  Ships risking Houthi attacks must pay high ins...
# 4  Before deciding whether to approve it, the Ene...
#
#                                       lead_paragraph              byline  \
# 0  Saudi Aramco said Tuesday that it would call o...     By Stanley Reed
# 1  New York City has its bodegas. The South has i...     By Kim Severson
# 2  President Biden has done more than any preside...    By Lisa Friedman
# 3  For about two months, a barrage of missile and...     By Stanley Reed
# 4  The Biden administration is pausing a decision...  By Coral Davenport
#
#    section_name                                            web_url  \
# 0  Business Day  https://www.nytimes.com/2024/01/30/business/sa...
# 1          Food  https://www.nytimes.com/2024/01/29/dining/sout...
# 2       Climate  https://www.nytimes.com/2024/01/27/climate/bid...
# 3  Business Day  https://www.nytimes.com/2024/01/24/business/re...
# 4       Climate  https://www.nytimes.com/2024/01/24/climate/bid...
#
#                source                                     multimedia_url  \
# 0  The New York Times  https://www.nytimes.com/images/2024/01/30/mult...
# 1  The New York Times  https://www.nytimes.com/images/2024/01/31/mult...
# 2  The New York Times  https://www.nytimes.com/images/2024/01/26/mult...
# 3  The New York Times  https://www.nytimes.com/images/2024/01/23/mult...
# 4  The New York Times  https://www.nytimes.com/images/2024/01/24/mult...
#
#    negative(sentiment_score_abstract)  neutral(sentiment_score_abstract)  \
# 0                            0.425521                           0.555502
# 1                            0.037574                           0.847687
# 2                            0.690003                           0.280284
# 3                            0.638661                           0.350388
# 4                            0.096726                           0.878780
#
#    positive(sentiment_score_abstract)  compound(sentiment_score_abstract)
# 0                            0.018976                           -0.406545
# 1                            0.114738                            0.077164
# 2                            0.029713                           -0.660291
# 3                            0.010952                           -0.627709
# 4                            0.024494                           -0.072232

# %%
results_df_final.head()
# Out:
#   article_count  negative(sentiment_score_headline)  \
# 0             1                            0.368058
# 1             2                            0.166938
# 2             3                            0.505036
# 3             4                            0.418735
# 4             5                            0.197280
#
#    neutral(sentiment_score_headline)  positive(sentiment_score_headline)  \
# 0                           0.601618                            0.030324
# 1                           0.778636                            0.054426
# 2                           0.465767                            0.029197
# 3                           0.560968                            0.020298
# 4                           0.782257                            0.020464
#
#    compound(sentiment_score_headline)                  pub_date  \
# 0                           -0.337734  2024-01-30T13:40:11+0000
# 1                           -0.112513  2024-01-29T10:01:56+0000
# 2                           -0.475839  2024-01-27T08:00:40+0000
# 3                           -0.398437  2024-01-24T19:59:53+0000
# 4                           -0.176816  2024-01-24T17:59:40+0000
#
#                                             headline  \
# 0  Saudi Aramco Abruptly Drops Plans to Expand Oi...
# 1  Where Southerners Go to Fill the Tank and Feed...
# 2  Democrats Say Biden Hasn’t ‘Made the Case’ on ...
# 3     Shipping Costs Soar in Wake of Red Sea Attacks
# 4  White House Said to Delay Decision on Enormous...
#
#                                             abstract  \
# 0  The pullback, at the behest of the Saudi gover...
# 1  Are they gas stations that serve food or resta...
# 2  The president likes to talk about his climate ...
# 3  Ships risking Houthi attacks must pay high ins...
# 4  Before deciding whether to approve it, the Ene...
#
#                                       lead_paragraph              byline  \
# 0  Saudi Aramco said Tuesday that it would call o...     By Stanley Reed
# 1  New York City has its bodegas. The South has i...     By Kim Severson
# 2  President Biden has done more than any preside...    By Lisa Friedman
# 3  For about two months, a barrage of missile and...     By Stanley Reed
# 4  The Biden administration is pausing a decision...  By Coral Davenport
#
#    section_name                                            web_url  \
# 0  Business Day  https://www.nytimes.com/2024/01/30/business/sa...
# 1          Food  https://www.nytimes.com/2024/01/29/dining/sout...
# 2       Climate  https://www.nytimes.com/2024/01/27/climate/bid...
# 3  Business Day  https://www.nytimes.com/2024/01/24/business/re...
# 4       Climate  https://www.nytimes.com/2024/01/24/climate/bid...
#
#                source                                     multimedia_url  \
# 0  The New York Times  https://www.nytimes.com/images/2024/01/30/mult...
# 1  The New York Times  https://www.nytimes.com/images/2024/01/31/mult...
# 2  The New York Times  https://www.nytimes.com/images/2024/01/26/mult...
# 3  The New York Times  https://www.nytimes.com/images/2024/01/23/mult...
# 4  The New York Times  https://www.nytimes.com/images/2024/01/24/mult...
#
#    negative(sentiment_score_abstract)  neutral(sentiment_score_abstract)  \
# 0                            0.425521                           0.555502
# 1                            0.037574                           0.847687
# 2                            0.690003                           0.280284
# 3                            0.638661                           0.350388
# 4                            0.096726                           0.878780
#
#    positive(sentiment_score_abstract)  compound(sentiment_score_abstract)
# 0                            0.018976                           -0.406545
# 1                            0.114738                            0.077164
# 2                            0.029713                           -0.660291
# 3                            0.010952                           -0.627709
# 4                            0.024494                           -0.072232

# %%
NYT_articles_results = results_df_final

# Save the merged DataFrame to a new CSV file
output_path = 'NYT_articles_results.csv'
NYT_articles_results.to_csv(output_path, index=False)

print(f"The merged DataFrame has been saved to {output_path}")
# Out:
# The merged DataFrame has been saved to NYT_articles_results.csv

# %%
NYT_articles_results["multimedia_url"][8]
# Out:
# 'https://www.nytimes.com/images/2024/01/19/multimedia/19ukraine-oil-mhbj/19ukraine-oil-mhbj-articleLarge.jpg'

# %%
file_path = 'Final_X_articles.csv'

# Read the CSV files
X_articles = pd.read_csv(file_path)

X_articles.tail()
# Out:
#       tweet_count           tweet.created_at       tweet.user.name  \
# 1726         1727  2024-07-09 18:17:04+00:00   Asia Fact Check Lab
# 1727         1728  2024-07-09 18:28:45+00:00  House Appropriations
# 1728         1729  2024-07-09 18:45:17+00:00                   EIA
# 1729         1730  2024-07-09 19:46:22+00:00           GetWireless
# 1730         1731  2024-07-09 19:50:02+00:00                   EIA
#
#      tweet.user.location  tweet.user.followers_count  \
# 1726                 NaN                         148
# 1727      Washington, DC                       22922
# 1728      Washington, DC                      181421
# 1729           Minnesota                         693
# 1730      Washington, DC                      181421
#
#                                              tweet.text  tweet.view_count  \
# 1726  A claim emerged among Chinese netizens in June...                66
# 1727  The FY25 Interior and Environment Appropriatio...              1787
# 1728  ☝️Correction: #Cryptocurrency mining. Apologie...              2245
# 1729  💡100% of the top 20 U.S. oil and gas producers...                26
# 1730  As we continue to highlight the #STEO forecast...              9149
#
#       tweet.favorite_count  tweet.retweet_count  tweet.reply_count  \
# 1726                     3                    1                  0
# 1727                     9                    2                  4
# 1728                     1                    0                  0
# 1729                     0                    0                  0
# 1730                     8                    3                  1
#
#                                             tweet.media
# 1726  [{'display_url': 'pic.x.com/znday8bmoj', 'expa...
# 1727  [{'display_url': 'pic.x.com/hwidzcew02', 'expa...
# 1728                                                NaN
# 1729  [{'display_url': 'pic.x.com/ezsk6nc95w', 'expa...
# 1730                                                NaN

# %%
example = X_articles["tweet.text"][13]
print(f"Example: {example}")
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'negative(sentiment_score)' : scores[0],
        'neutral(sentiment_score)' : scores[1],
        'positive(sentiment_score)' : scores[2],
        'compound(sentiment_score)' : np.dot(scores, [-1, 0, 1]) 
    }
    return scores_dict

polarity_scores_roberta(example)
# Out:
# Example: #TodayInEnergy - U.S. #HenryHub #naturalgasprices in 2023 were the lowest since mid-2020   https://t.co/EGSbAKi2jP https://t.co/rObAaluhMQ
# {'negative(sentiment_score)': 0.43668902,
#  'neutral(sentiment_score)': 0.5049686,
#  'positive(sentiment_score)': 0.058342475,
#  'compound(sentiment_score)': -0.3783465437591076}

# %%
res = {}
for i, row in tqdm(X_articles.iterrows(), total=len(X_articles)):
    try:
        text = row['tweet.text']
        myid = row['tweet_count']
        res[myid] = polarity_scores_roberta(text)
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#  34%|███▍      | 595/1731 [00:33<01:03, 17.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 6
#       4     text = row['tweet.text']
#       5     myid = row['tweet_count']
# ----> 6     res[myid] = polarity_scores_roberta(text)
#       7 except RuntimeError:
#       8     print(f'Broke for id {myid}')
#
# Cell In[14], line 5, in polarity_scores_roberta(example)
#       3 def polarity_scores_roberta(example):
#       4     encoded_text = tokenizer(example, return_tensors='pt')
# ----> 5     output = model(**encoded_text)
#       6     scores = output[0][0].detach().numpy()
#       7     scores = softmax(scores)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:1195, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1187 r"""
#    1188 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1189     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1190     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1191     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1192 """
#    1193 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1195 outputs = self.roberta(
#    1196     input_ids,
#    1197     attention_mask=attention_mask,
#    1198     token_type_ids=token_type_ids,
#    1199     position_ids=position_ids,
#    1200     head_mask=head_mask,
#    1201     inputs_embeds=inputs_embeds,
#    1202     output_attentions=output_attentions,
#    1203     output_hidden_states=output_hidden_states,
#    1204     return_dict=return_dict,
#    1205 )
#    1206 sequence_output = outputs[0]
#    1207 logits = self.classifier(sequence_output)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:832, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     823 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     825 embedding_output = self.embeddings(
#     826     input_ids=input_ids,
#     827     position_ids=position_ids,
#    (...)
#     830     past_key_values_length=past_key_values_length,
#     831 )
# --> 832 encoder_outputs = self.encoder(
#     833     embedding_output,
#     834     attention_mask=extended_attention_mask,
#     835     head_mask=head_mask,
#     836     encoder_hidden_states=encoder_hidden_states,
#     837     encoder_attention_mask=encoder_extended_attention_mask,
#     838     past_key_values=past_key_values,
#     839     use_cache=use_cache,
#     840     output_attentions=output_attentions,
#     841     output_hidden_states=output_hidden_states,
#     842     return_dict=return_dict,
#     843 )
#     844 sequence_output = encoder_outputs[0]
#     845 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:521, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     510     layer_outputs = self._gradient_checkpointing_func(
#     511         layer_module.__call__,
#     512         hidden_states,
#    (...)
#     518         output_attentions,
#     519     )
#     520 else:
# --> 521     layer_outputs = layer_module(
#     522         hidden_states,
#     523         attention_mask,
#     524         layer_head_mask,
#     525         encoder_hidden_states,
#     526         encoder_attention_mask,
#     527         past_key_value,
#     528         output_attentions,
#     529     )
#     531 hidden_states = layer_outputs[0]
#     532 if use_cache:
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:410, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     398 def forward(
#     399     self,
#     400     hidden_states: torch.Tensor,
#    (...)
#     407 ) -> Tuple[torch.Tensor]:
#     408     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     409     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 410     self_attention_outputs = self.attention(
#     411         hidden_states,
#     412         attention_mask,
#     413         head_mask,
#     414         output_attentions=output_attentions,
#     415         past_key_value=self_attn_past_key_value,
#     416     )
#     417     attention_output = self_attention_outputs[0]
#     419     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:337, in RobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     327 def forward(
#     328     self,
#     329     hidden_states: torch.Tensor,
#    (...)
#     335     output_attentions: Optional[bool] = False,
#     336 ) -> Tuple[torch.Tensor]:
# --> 337     self_outputs = self.self(
#     338         hidden_states,
#     339         attention_mask,
#     340         head_mask,
#     341         encoder_hidden_states,
#     342         encoder_attention_mask,
#     343         past_key_value,
#     344         output_attentions,
#     345     )
#     346     attention_output = self.output(self_outputs[0], hidden_states)
#     347     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\aerok\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:226, in RobertaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     223     past_key_value = (key_layer, value_layer)
#     225 # Take the dot product between "query" and "key" to get the raw attention scores.
# --> 226 attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
#     228 if self.position_embedding_type == "relative_key" or self.position_embedding_type == "relative_key_query":
#     229     query_length, key_length = query_layer.shape[2], key_layer.shape[2]
#
# KeyboardInterrupt:

# %%
X_articles_results = pd.DataFrame(res).T
X_articles_results = X_articles_results.reset_index().rename(columns={'index': 'tweet_count'})
X_articles_results = X_articles_results.merge(X_articles, how='left')
X_articles_results.head()
# Out:
#    tweet_count  negative(sentiment_score)  neutral(sentiment_score)  \
# 0            1                   0.224576                  0.714257
# 1            2                   0.004042                  0.304035
# 2            3                   0.177734                  0.775157
# 3            4                   0.036057                  0.877669
# 4            5                   0.194202                  0.722310
#
#    positive(sentiment_score)  compound(sentiment_score)  \
# 0                   0.061168                  -0.163408
# 1                   0.691923                   0.687881
# 2                   0.047109                  -0.130626
# 3                   0.086274                   0.050218
# 4                   0.083488                  -0.110714
#
#             tweet.created_at tweet.user.name tweet.user.location  \
# 0  2024-01-02 13:10:06+00:00             EIA      Washington, DC
# 1  2024-01-02 18:11:37+00:00             EIA      Washington, DC
# 2  2024-01-02 19:04:55+00:00             EIA      Washington, DC
# 3  2024-01-02 21:09:05+00:00             EIA      Washington, DC
# 4  2024-01-02 21:30:01+00:00             EIA      Washington, DC
#
#    tweet.user.followers_count  \
# 0                      181422
# 1                      181422
# 2                      181422
# 3                      181422
# 4                      181422
#
#                                           tweet.text  tweet.view_count  \
# 0  #TodayInEnergy - #Brent crude #oilprices avera...             20679
# 1  Reminder: #TodayInEnergy will see some big cha...              6858
# 2  Annual average price of Brent crude #oil: \n\n...             11759
# 3  We're adjusting our data release schedule due ...              3671
# 4  Comparing September 2023 to September 2022:\n\...              3956
#
#    tweet.favorite_count  tweet.retweet_count  tweet.reply_count  \
# 0                    30                   17                  0
# 1                    15                   10                  1
# 2                    27                    9                  1
# 3                     7                    1                  1
# 4                    15                    3                  1
#
#                                          tweet.media
# 0  [{'display_url': 'pic.x.com/gexe4zlndm', 'expa...
# 1                                                NaN
# 2  [{'display_url': 'pic.x.com/iaqlwlrdst', 'expa...
# 3  [{'display_url': 'pic.x.com/nnvwtlnraj', 'expa...
# 4                                                NaN

# %%
# Save the merged DataFrame to a new CSV file
output_path = 'X_articles_results.csv'
X_articles_results.to_csv(output_path, index=False)

print(f"The merged DataFrame has been saved to {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Save the merged DataFrame to a new CSV file
#       2 output_path = 'X_articles_results.csv'
# ----> 3 X_articles_results.to_csv(output_path, index=False)
#       5 print(f"The merged DataFrame has been saved to {output_path}")
#
# NameError: name 'X_articles_results' is not defined

# %%
X_articles_results["tweet.media"][8]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X_articles_results["tweet.media"][8]
#
# NameError: name 'X_articles_results' is not defined

# %%
import pandas as pd
import json

# Load the CSV file into a DataFrame
file_path = 'C:\\Users\\aerok\\OneDrive\\Рабочий стол\\Socioeconomic Dynamics\\Sentiment Analysis\\X_articles_results.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Function to extract media_url_https
def extract_media_url(media_column):
    if pd.isna(media_column):
        return ""
    try:
        # Ensure the input is a string
        media_column = str(media_column)
        # Parse the JSON-like structure
        media_items = json.loads(media_column.replace("'", '"'))  # Replace single quotes with double quotes for valid JSON
        if isinstance(media_items, list):
            # Extract media_url_https from each media item
            media_urls = [item['media_url_https'] for item in media_items if 'media_url_https' in item]
            return ', '.join(media_urls)  # Join multiple URLs with a comma
        else:
            return ""
    except (json.JSONDecodeError, TypeError):
        return ""

# Apply the extraction function to the tweet.media column
df['media_url_https'] = df['tweet.media'].apply(extract_media_url)

# Display the first few rows of the updated DataFrame
df.tail()
# Out:
#    tweet_count  negative(sentiment_score)  neutral(sentiment_score)  \
# 0            1                   0.224576                  0.714257
# 1            2                   0.004042                  0.304035
# 2            3                   0.177734                  0.775157
# 3            4                   0.036057                  0.877669
# 4            5                   0.194202                  0.722310
#
#    positive(sentiment_score)  compound(sentiment_score)  \
# 0                   0.061168                  -0.163408
# 1                   0.691923                   0.687881
# 2                   0.047109                  -0.130626
# 3                   0.086274                   0.050218
# 4                   0.083488                  -0.110714
#
#             tweet.created_at tweet.user.name tweet.user.location  \
# 0  2024-01-02 13:10:06+00:00             EIA      Washington, DC
# 1  2024-01-02 18:11:37+00:00             EIA      Washington, DC
# 2  2024-01-02 19:04:55+00:00             EIA      Washington, DC
# 3  2024-01-02 21:09:05+00:00             EIA      Washington, DC
# 4  2024-01-02 21:30:01+00:00             EIA      Washington, DC
#
#    tweet.user.followers_count  \
# 0                      181422
# 1                      181422
# 2                      181422
# 3                      181422
# 4                      181422
#
#                                           tweet.text  tweet.view_count  \
# 0  #TodayInEnergy - #Brent crude #oilprices avera...             20679
# 1  Reminder: #TodayInEnergy will see some big cha...              6858
# 2  Annual average price of Brent crude #oil: \n\n...             11759
# 3  We're adjusting our data release schedule due ...              3671
# 4  Comparing September 2023 to September 2022:\n\...              3956
#
#    tweet.favorite_count  tweet.retweet_count  tweet.reply_count  \
# 0                    30                   17                  0
# 1                    15                   10                  1
# 2                    27                    9                  1
# 3                     7                    1                  1
# 4                    15                    3                  1
#
#                                          tweet.media
# 0  [{'display_url': 'pic.x.com/gexe4zlndm', 'expa...
# 1                                                NaN
# 2  [{'display_url': 'pic.x.com/iaqlwlrdst', 'expa...
# 3  [{'display_url': 'pic.x.com/nnvwtlnraj', 'expa...
# 4                                                NaN
#       tweet_count  negative(sentiment_score)  neutral(sentiment_score)  \
# 1726         1727                   0.272725                  0.700648
# 1727         1728                   0.018073                  0.553974
# 1728         1729                   0.462649                  0.478608
# 1729         1730                   0.004067                  0.266414
# 1730         1731                   0.048669                  0.794752
#
#       positive(sentiment_score)  compound(sentiment_score)  \
# 1726                   0.026627                  -0.246098
# 1727                   0.427953                   0.409881
# 1728                   0.058743                  -0.403906
# 1729                   0.729519                   0.725453
# 1730                   0.156578                   0.107909
#
#                tweet.created_at       tweet.user.name tweet.user.location  \
# 1726  2024-07-09 18:17:04+00:00   Asia Fact Check Lab                 NaN
# 1727  2024-07-09 18:28:45+00:00  House Appropriations      Washington, DC
# 1728  2024-07-09 18:45:17+00:00                   EIA      Washington, DC
# 1729  2024-07-09 19:46:22+00:00           GetWireless           Minnesota
# 1730  2024-07-09 19:50:02+00:00                   EIA      Washington, DC
#
#       tweet.user.followers_count  \
# 1726                         148
# 1727                       22922
# 1728                      181421
# 1729                         693
# 1730                      181421
#
#                                              tweet.text  tweet.view_count  \
# 1726  A claim emerged among Chinese netizens in June...                66
# 1727  The FY25 Interior and Environment Appropriatio...              1787
# 1728  ☝️Correction: #Cryptocurrency mining. Apologie...              2245
# 1729  💡100% of the top 20 U.S. oil and gas producers...                26
# 1730  As we continue to highlight the #STEO forecast...              9149
#
#       tweet.favorite_count  tweet.retweet_count  tweet.reply_count  \
# 1726                     3                    1                  0
# 1727                     9                    2                  4
# 1728                     1                    0                  0
# 1729                     0                    0                  0
# 1730                     8                    3                  1
#
#                                             tweet.media  \
# 1726  [{'display_url': 'pic.x.com/znday8bmoj', 'expa...
# 1727  [{'display_url': 'pic.x.com/hwidzcew02', 'expa...
# 1728                                                NaN
# 1729  [{'display_url': 'pic.x.com/ezsk6nc95w', 'expa...
# 1730                                                NaN
#
#                                         media_url_https
# 1726    https://pbs.twimg.com/media/GSEKZmcaUAEbSeh.jpg
# 1727
# 1728
# 1729  https://pbs.twimg.com/tweet_video_thumb/GSEbrZ...
# 1730

# %%
# Save the merged DataFrame to a new CSV file
output_path = 'X_articles_results_2.csv'
df.to_csv(output_path, index=False)

print(f"The merged DataFrame has been saved to {output_path}")
# Out:
# The merged DataFrame has been saved to X_articles_results_2.csv
