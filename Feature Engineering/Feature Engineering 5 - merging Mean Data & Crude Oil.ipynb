# %%
import pandas as pd




CrudeOil = pd.read_csv('Crude Oil Data/CrudeOil_Finished.csv')
mean_compound_per_day = pd.read_csv('Merged Data With Different Means/mean_compound_per_day.csv')
mean_compound_before_930am = pd.read_csv('Merged Data With Different Means/mean_compound_before_930am.csv') 
mean_compound_trading_hours = pd.read_csv('Merged Data With Different Means/mean_compound_trading_hours.csv')
mean_compound_after_4pm_before_930am = pd.read_csv('Merged Data With Different Means/mean_compound_after_4pm_before_930am.csv')

mean_compound_per_day_without_other = pd.read_csv('Merged Data With Different Means Without Other/mean_compound_per_day_without_other.csv')
mean_compound_before_930am_without_other = pd.read_csv('Merged Data With Different Means Without Other/mean_compound_before_930am_without_other.csv') 
mean_compound_trading_hours_without_other = pd.read_csv('Merged Data With Different Means Without Other/mean_compound_trading_hours_without_other.csv')
mean_compound_after_4pm_before_930am_without_other = pd.read_csv('Merged Data With Different Means Without Other/mean_compound_after_4pm_before_930am_without_other.csv')

# %%
mean_compound_after_4pm_before_930am_without_other.head()
# Out:
#          date  mean_compound_after_4pm_before_930am
# 0  2024-01-03                             -0.111525
# 1  2024-01-05                             -0.207107
# 2  2024-01-09                             -0.048255
# 3  2024-01-10                             -0.625167
# 4  2024-01-11                              0.264710

# %%
CrudeOil.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  130.000000  130.000000  130.000000  130.000000  130.000000
# mean    78.941154   79.951615   77.993923   78.999692   78.999692
# std      3.894830    3.727377    3.932864    3.861222    3.861222
# min     70.500000   72.930000   69.279999   70.379997   70.379997
# 25%     76.982500   78.087502   75.842497   76.882502   76.882502
# 50%     78.730000   79.625000   77.829998   78.805000   78.805000
# 75%     81.654997   82.480003   80.965000   81.724998   81.724998
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     130.000000            130.000000       130.000000
# mean   308674.807692              0.042915        -0.058539
# std     86300.707432              0.467177         1.117303
# min     76814.000000             -1.000000        -2.389999
# 25%    286453.750000             -0.213248        -0.855001
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_per_day = pd.merge(CrudeOil, mean_compound_per_day, on='date', how='inner')
mean_compound_per_day.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  130.000000  130.000000  130.000000  130.000000  130.000000
# mean    78.941154   79.951615   77.993923   78.999692   78.999692
# std      3.894830    3.727377    3.932864    3.861222    3.861222
# min     70.500000   72.930000   69.279999   70.379997   70.379997
# 25%     76.982500   78.087502   75.842497   76.882502   76.882502
# 50%     78.730000   79.625000   77.829998   78.805000   78.805000
# 75%     81.654997   82.480003   80.965000   81.724998   81.724998
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     130.000000            130.000000       130.000000
# mean   308674.807692              0.042915        -0.058539
# std     86300.707432              0.467177         1.117303
# min     76814.000000             -1.000000        -2.389999
# 25%    286453.750000             -0.213248        -0.855001
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_before_930am = pd.merge(CrudeOil, mean_compound_before_930am, on='date', how='inner')
mean_compound_before_930am.describe()
# Out:
#             Open       High        Low      Close  Adj Close         Volume  \
# count  68.000000  68.000000  68.000000  68.000000  68.000000      68.000000
# mean   79.477059  80.501176  78.623382  79.596471  79.596471  304661.235294
# std     3.219216   3.199193   3.135122   3.190803   3.190803   81265.215036
# min    72.400002  74.220001  72.209999  72.680000  72.680000   76901.000000
# 25%    77.807499  78.582502  76.692497  77.892502  77.892502  274210.500000
# 50%    79.099998  79.715000  77.950001  78.805000  78.805000  314495.000000
# 75%    81.457499  82.132502  80.632502  81.847498  81.847498  348790.750000
# max    86.320000  87.669998  85.239998  86.589996  86.589996  443271.000000
#
#        Normalized Adj Close  Open_Close_Diff  Normalized_Open_Close_Diff  \
# count             68.000000        68.000000                   68.000000
# mean               0.115120        -0.119412                    0.441749
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_trading_hours = pd.merge(CrudeOil, mean_compound_trading_hours, on='date', how='inner')
mean_compound_per_day.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  130.000000  130.000000  130.000000  130.000000  130.000000
# mean    78.941154   79.951615   77.993923   78.999692   78.999692
# std      3.894830    3.727377    3.932864    3.861222    3.861222
# min     70.500000   72.930000   69.279999   70.379997   70.379997
# 25%     76.982500   78.087502   75.842497   76.882502   76.882502
# 50%     78.730000   79.625000   77.829998   78.805000   78.805000
# 75%     81.654997   82.480003   80.965000   81.724998   81.724998
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     130.000000            130.000000       130.000000
# mean   308674.807692              0.042915        -0.058539
# std     86300.707432              0.467177         1.117303
# min     76814.000000             -1.000000        -2.389999
# 25%    286453.750000             -0.213248        -0.855001
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_after_4pm_before_930am = pd.merge(CrudeOil, mean_compound_after_4pm_before_930am, on='date', how='inner')
mean_compound_after_4pm_before_930am.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000
# mean    79.133525   80.138770   78.219426   79.219508   79.219508
# std      3.817507    3.660590    3.814668    3.737764    3.737764
# min     70.500000   72.930000   69.279999   71.370003   71.370003
# 25%     77.067501   78.170000   76.082499   77.410000   77.410000
# 50%     78.789997   79.760002   77.925003   78.939999   78.939999
# 75%     81.707499   82.660002   81.000002   81.882500   81.882500
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     122.000000            122.000000       122.000000
# mean   310811.909836              0.069511        -0.085984
# std     83864.158634              0.452240         1.073053
# min     76814.000000             -0.880217        -2.199997
# 25%    286453.750000             -0.149425        -0.855001
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_per_day_without_other = pd.merge(CrudeOil, mean_compound_per_day_without_other, on='date', how='inner')
mean_compound_per_day_without_other.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000
# mean    79.017874   80.033149   78.087323   79.089292   79.089292
# std      3.900633    3.721913    3.908018    3.830615    3.830615
# min     70.500000   72.930000   69.279999   70.379997   70.379997
# 25%     77.024998   78.125000   75.844997   76.954998   76.954998
# 50%     78.839996   79.720001   77.910004   78.930000   78.930000
# 75%     81.704998   82.600002   80.990002   81.834999   81.834999
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     127.000000            127.000000       127.000000
# mean   307617.385827              0.053756        -0.071418
# std     86848.721347              0.463474         1.099832
# min     76814.000000             -1.000000        -2.389999
# 25%    283603.500000             -0.204477        -0.855003
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_before_930am_without_other = pd.merge(CrudeOil, mean_compound_before_930am_without_other, on='date', how='inner')
mean_compound_before_930am_without_other.describe()
# Out:
#             Open       High        Low      Close  Adj Close         Volume  \
# count  68.000000  68.000000  68.000000  68.000000  68.000000      68.000000
# mean   79.477059  80.501176  78.623382  79.596471  79.596471  304661.235294
# std     3.219216   3.199193   3.135122   3.190803   3.190803   81265.215036
# min    72.400002  74.220001  72.209999  72.680000  72.680000   76901.000000
# 25%    77.807499  78.582502  76.692497  77.892502  77.892502  274210.500000
# 50%    79.099998  79.715000  77.950001  78.805000  78.805000  314495.000000
# 75%    81.457499  82.132502  80.632502  81.847498  81.847498  348790.750000
# max    86.320000  87.669998  85.239998  86.589996  86.589996  443271.000000
#
#        Normalized Adj Close  Open_Close_Diff  Normalized_Open_Close_Diff  \
# count             68.000000        68.000000                   68.000000
# mean               0.115120        -0.119412                    0.441749
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_trading_hours_without_other = pd.merge(CrudeOil, mean_compound_trading_hours_without_other, on='date', how='inner')
mean_compound_per_day.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  130.000000  130.000000  130.000000  130.000000  130.000000
# mean    78.941154   79.951615   77.993923   78.999692   78.999692
# std      3.894830    3.727377    3.932864    3.861222    3.861222
# min     70.500000   72.930000   69.279999   70.379997   70.379997
# 25%     76.982500   78.087502   75.842497   76.882502   76.882502
# 50%     78.730000   79.625000   77.829998   78.805000   78.805000
# 75%     81.654997   82.480003   80.965000   81.724998   81.724998
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     130.000000            130.000000       130.000000
# mean   308674.807692              0.042915        -0.058539
# std     86300.707432              0.467177         1.117303
# min     76814.000000             -1.000000        -2.389999
# 25%    286453.750000             -0.213248        -0.855001
# ...

# %%
# Merging the two datasets on the 'date' column
mean_compound_after_4pm_before_930am_without_other = pd.merge(CrudeOil, mean_compound_after_4pm_before_930am_without_other, on='date', how='inner')
mean_compound_after_4pm_before_930am_without_other.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  114.000000  114.000000  114.000000  114.000000  114.000000
# mean    79.268158   80.269473   78.370614   79.349211   79.349211
# std      3.750553    3.569816    3.713415    3.616321    3.616321
# min     70.500000   72.930000   69.279999   71.370003   71.370003
# 25%     77.417501   78.395000   76.357498   77.572500   77.572500
# 50%     79.025002   79.825001   77.970001   78.994999   78.994999
# 75%     81.822500   82.997498   81.099998   81.882500   81.882500
# max     86.860001   87.669998   86.320000   86.910004   86.910004
#
#               Volume  Normalized Adj Close  Open_Close_Diff  \
# count     114.000000            114.000000       114.000000
# mean   307412.131579              0.085204        -0.081053
# std     84027.705767              0.437546         1.081821
# min     76814.000000             -0.880217        -2.199997
# 25%    282386.250000             -0.129764        -0.830004
# ...
